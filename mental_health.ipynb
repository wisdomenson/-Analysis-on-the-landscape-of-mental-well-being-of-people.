# %%
#import and data understanding
#hm = mental health
import pandas as pd
mh = pd.read_csv('Mental Health Dataset.csv')
mh
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# 0       8/27/2014 11:29  Female  United States  Corporate           NaN
# 1       8/27/2014 11:31  Female  United States  Corporate           NaN
# 2       8/27/2014 11:32  Female  United States  Corporate           NaN
# 3       8/27/2014 11:37  Female  United States  Corporate            No
# 4       8/27/2014 11:43  Female  United States  Corporate            No
# ...                 ...     ...            ...        ...           ...
# 292359  7/27/2015 23:25    Male  United States   Business           Yes
# 292360   8/17/2015 9:38    Male   South Africa   Business            No
# 292361  8/25/2015 19:59    Male  United States   Business            No
# 292362   9/26/2015 1:07    Male  United States   Business            No
# 292363   2/1/2016 23:04    Male  United States   Business            No
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# ...

# %%
mh_df = mh.copy()

# %%
mh_df.head()
# Out:
#          Timestamp  Gender        Country Occupation self_employed  \
# 0  8/27/2014 11:29  Female  United States  Corporate           NaN
# 1  8/27/2014 11:31  Female  United States  Corporate           NaN
# 2  8/27/2014 11:32  Female  United States  Corporate           NaN
# 3  8/27/2014 11:37  Female  United States  Corporate            No
# 4  8/27/2014 11:43  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# ...

# %%
mh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292364 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                292364 non-null  object
#  1   Gender                   292364 non-null  object
#  2   Country                  292364 non-null  object
#  3   Occupation               292364 non-null  object
#  4   self_employed            287162 non-null  object
#  5   family_history           292364 non-null  object
#  6   treatment                292364 non-null  object
#  7   Days_Indoors             292364 non-null  object
#  8   Growing_Stress           292364 non-null  object
#  9   Changes_Habits           292364 non-null  object
#  10  Mental_Health_History    292364 non-null  object
#  11  Mood_Swings              292364 non-null  object
#  12  Coping_Struggles         292364 non-null  object
# ...

# %%
mh_df.describe()
# Out:
#               Timestamp  Gender        Country Occupation self_employed  \
# count            292364  292364         292364     292364        287162
# unique              580       2             35          5             2
# top     8/27/2014 11:43    Male  United States  Housewife            No
# freq               2384  239850         171308      66351        257994
#
#        family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# count          292364    292364       292364         292364         292364
# unique              2         2            5              3              3
# top                No       Yes    1-14 days          Maybe            Yes
# freq           176832    147606        63548          99985         109523
#
#        Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# count                 292364      292364           292364        292364
# unique                     3           3                2             3
# ...

# %%
mh_df.duplicated().value_counts()
# Out:
# False    290051
# True       2313
# Name: count, dtype: int64

# %%
mh_df.drop_duplicates(inplace=True)

# %%
mh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290051 entries, 0 to 292363
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                290051 non-null  object
#  1   Gender                   290051 non-null  object
#  2   Country                  290051 non-null  object
#  3   Occupation               290051 non-null  object
#  4   self_employed            284858 non-null  object
#  5   family_history           290051 non-null  object
#  6   treatment                290051 non-null  object
#  7   Days_Indoors             290051 non-null  object
#  8   Growing_Stress           290051 non-null  object
#  9   Changes_Habits           290051 non-null  object
#  10  Mental_Health_History    290051 non-null  object
#  11  Mood_Swings              290051 non-null  object
#  12  Coping_Struggles         290051 non-null  object
# ...

# %%
mh_df.columns
# Out:
# Index(['Timestamp', 'Gender', 'Country', 'Occupation', 'self_employed',
#        'family_history', 'treatment', 'Days_Indoors', 'Growing_Stress',
#        'Changes_Habits', 'Mental_Health_History', 'Mood_Swings',
#        'Coping_Struggles', 'Work_Interest', 'Social_Weakness',
#        'mental_health_interview', 'care_options'],
#       dtype='object')

# %%
#cleaning by columns
mh_df['Timestamp'].describe()
# Out:
# count              290051
# unique                580
# top       8/27/2014 11:43
# freq                 2381
# Name: Timestamp, dtype: object

# %%
mh_df.Timestamp.sample(10)
# Out:
# 173291    8/27/2014 16:13
# 214690    8/28/2014 17:21
# 255829    8/28/2014 10:52
# 200300    8/27/2014 14:57
# 175232     8/28/2014 8:43
# 40323     8/27/2014 14:27
# 231786     8/28/2014 0:05
# 101798    8/27/2014 12:40
# 80192     8/27/2014 11:31
# 88479     8/27/2014 22:32
# Name: Timestamp, dtype: object

# %%
mh_df['Timestamp'] = mh_df['Timestamp'] = pd.to_datetime(mh_df['Timestamp'], format='mixed')

# %%
mh_df.loc[:, 'Year'] = mh_df['Timestamp'].dt.year  # Use .loc to create and assign year, month, and day columns
mh_df.loc[:, 'Month'] = mh_df['Timestamp'].dt.month
mh_df.loc[:, 'Day'] = mh_df['Timestamp'].dt.day

# %%
mh_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290051 entries, 0 to 292363
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Timestamp                290051 non-null  datetime64[ns]
#  1   Gender                   290051 non-null  object
#  2   Country                  290051 non-null  object
#  3   Occupation               290051 non-null  object
#  4   self_employed            284858 non-null  object
#  5   family_history           290051 non-null  object
#  6   treatment                290051 non-null  object
#  7   Days_Indoors             290051 non-null  object
#  8   Growing_Stress           290051 non-null  object
#  9   Changes_Habits           290051 non-null  object
#  10  Mental_Health_History    290051 non-null  object
#  11  Mood_Swings              290051 non-null  object
#  12  Coping_Struggles         290051 non-null  object
# ...

# %%
mh_df['Gender'].describe()
# Out:
# count     290051
# unique         2
# top         Male
# freq      237900
# Name: Gender, dtype: object

# %%
mh_df.Gender.sample(5)
# Out:
# 39325     Female
# 135749      Male
# 263164      Male
# 82067       Male
# 214997      Male
# Name: Gender, dtype: object

# %%
mh_df['Country'].describe()
# Out:
# count            290051
# unique               35
# top       United States
# freq             169112
# Name: Country, dtype: object

# %%
mh_df.Country.unique()
# Out:
# array(['United States', 'Poland', 'Australia', 'Canada', 'United Kingdom',
#        'South Africa', 'Sweden', 'New Zealand', 'Netherlands', 'India',
#        'Belgium', 'Ireland', 'France', 'Portugal', 'Brazil', 'Costa Rica',
#        'Russia', 'Germany', 'Switzerland', 'Finland', 'Israel', 'Italy',
#        'Bosnia and Herzegovina', 'Singapore', 'Nigeria', 'Croatia',
#        'Thailand', 'Denmark', 'Mexico', 'Greece', 'Moldova', 'Colombia',
#        'Georgia', 'Czech Republic', 'Philippines'], dtype=object)

# %%
mh_df['Occupation'].describe()
# Out:
# count        290051
# unique            5
# top       Housewife
# freq          65906
# Name: Occupation, dtype: object

# %%
mh_df.Occupation.unique()
# Out:
# array(['Corporate', 'Student', 'Business', 'Housewife', 'Others'],
#       dtype=object)

# %%
mh_df['Occupation'] = mh_df['Occupation'].replace('Others', 'Other')

# %%
mh_df['self_employed'].describe()
# Out:
# count     284858
# unique         2
# top           No
# freq      255711
# Name: self_employed, dtype: object

# %%
mh_df.self_employed.unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
mh_df.self_employed.isna().value_counts()
# Out:
# self_employed
# False    284858
# True       5193
# Name: count, dtype: int64

# %%
mh_df.self_employed = mh_df.self_employed.fillna('Other')

# %%
mh_df['family_history'].describe()
# Out:
# count     290051
# unique         2
# top           No
# freq      175518
# Name: family_history, dtype: object

# %%
mh_df.family_history.sample(5)
# Out:
# 63295      No
# 253992    Yes
# 71198      No
# 9568       No
# 12234     Yes
# Name: family_history, dtype: object

# %%
mh_df['treatment'].describe()
# Out:
# count     290051
# unique         2
# top          Yes
# freq      146184
# Name: treatment, dtype: object

# %%
mh_df.treatment.sample(5)
# Out:
# 275880    No
# 161789    No
# 103539    No
# 250147    No
# 236651    No
# Name: treatment, dtype: object

# %%
mh_df['Days_Indoors'].describe()
# Out:
# count        290051
# unique            5
# top       1-14 days
# freq          63113
# Name: Days_Indoors, dtype: object

# %%
mh_df.Days_Indoors.unique()
# Out:
# array(['1-14 days', 'Go out Every day', 'More than 2 months',
#        '15-30 days', '31-60 days'], dtype=object)

# %%
mh_df.Days_Indoors.sample(5)
# Out:
# 166723      Go out Every day
# 33751     More than 2 months
# 269868             1-14 days
# 218523      Go out Every day
# 89610     More than 2 months
# Name: Days_Indoors, dtype: object

# %%
mh_df['Growing_Stress'].describe()
# Out:
# count     290051
# unique         3
# top        Maybe
# freq       99300
# Name: Growing_Stress, dtype: object

# %%
mh_df.Growing_Stress.sample(5)
# Out:
# 199568      Yes
# 64400       Yes
# 143422    Maybe
# 115174       No
# 162044    Maybe
# Name: Growing_Stress, dtype: object

# %%
mh_df['Changes_Habits'].describe()
# Out:
# count     290051
# unique         3
# top          Yes
# freq      108788
# Name: Changes_Habits, dtype: object

# %%
mh_df.Changes_Habits.sample(5)
# Out:
# 58417        No
# 271926    Maybe
# 116357      Yes
# 193079      Yes
# 101681    Maybe
# Name: Changes_Habits, dtype: object

# %%
mh_df['Mental_Health_History'].describe()
# Out:
# count     290051
# unique         3
# top           No
# freq      103313
# Name: Mental_Health_History, dtype: object

# %%
mh_df.Mental_Health_History.sample(5)
# Out:
# 61923        No
# 189389    Maybe
# 95031        No
# 72906     Maybe
# 276571    Maybe
# Name: Mental_Health_History, dtype: object

# %%
mh_df['Mood_Swings'].describe()
# Out:
# count     290051
# unique         3
# top       Medium
# freq      100384
# Name: Mood_Swings, dtype: object

# %%
mh_df.Mood_Swings.unique()
# Out:
# array(['Medium', 'Low', 'High'], dtype=object)

# %%
mh_df.Mood_Swings.sample(5)
# Out:
# 288400      High
# 69440       High
# 236765       Low
# 50657     Medium
# 238310    Medium
# Name: Mood_Swings, dtype: object

# %%
mh_df['Coping_Struggles'].describe()
# Out:
# count     290051
# unique         2
# top           No
# freq      153031
# Name: Coping_Struggles, dtype: object

# %%
mh_df.Coping_Struggles.sample(5)
# Out:
# 230634    Yes
# 255515    Yes
# 26518     Yes
# 116182    Yes
# 286151     No
# Name: Coping_Struggles, dtype: object

# %%
mh_df['Work_Interest'].describe()
# Out:
# count     290051
# unique         3
# top           No
# freq      105012
# Name: Work_Interest, dtype: object

# %%
mh_df.Work_Interest.sample(5)
# Out:
# 235727    Maybe
# 225263       No
# 93949        No
# 198584    Maybe
# 1365        Yes
# Name: Work_Interest, dtype: object

# %%
mh_df['Social_Weakness'].describe()
# Out:
# count     290051
# unique         3
# top        Maybe
# freq      102577
# Name: Social_Weakness, dtype: object

# %%
mh_df.Social_Weakness.sample(5)
# Out:
# 263513      Yes
# 201540       No
# 243585    Maybe
# 48647     Maybe
# 287504    Maybe
# Name: Social_Weakness, dtype: object

# %%
mh_df['mental_health_interview'].describe()
# Out:
# count     290051
# unique         3
# top           No
# freq      229889
# Name: mental_health_interview, dtype: object

# %%
mh_df.mental_health_interview.sample(5)
# Out:
# 30831     No
# 229886    No
# 249995    No
# 170879    No
# 280711    No
# Name: mental_health_interview, dtype: object

# %%
mh_df['care_options'].describe()
# Out:
# count     290051
# unique         3
# top           No
# freq      117614
# Name: care_options, dtype: object

# %%
mh_df.care_options.unique()
# Out:
# array(['Not sure', 'No', 'Yes'], dtype=object)

# %%
mh_df['Year'].unique()
# Out:
# array([2014, 2015, 2016])

# %%
mh_df['Month'].unique()
# Out:
# array([ 8,  9, 10, 12,  2,  6, 11,  4,  5,  7])

# %%
mh_df['Day'].nunique()
# Out:
# 25

# %% [markdown]
# ANALYSIS & VISUALIZATION

# %%
mh_df.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
#gender distribution
gender = mh_df['Gender'].value_counts()
gender.sum()
# Out:
# 290051

# %%
#gender distribution
import matplotlib.pyplot as plt 
import seaborn as sbn 

sbn.set_style('whitegrid')
plt.figure(figsize=(6,4))
#mh_df[['Gender']].value_counts().plot(kind='bar', color='g')
gender = mh_df['Gender'].value_counts().plot(kind='bar', color='g')

#for p in gender.patches:
#    gender.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

for p in gender.patches:
    gender.annotate(str(p.get_height()),(p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')
    
plt.xticks(rotation=0)
plt.title('Gender Distribution of Respondents')
plt.ylabel('Frequency')
plt.ylim(0,300000)
# Out:
# (0.0, 300000.0)

# %%
#percentage distribution of gender
import matplotlib.pyplot as plt 
import seaborn as sbn 

#gender = mh_df['Gender'].value_counts().plot.pie(autopct='%1.1f%%')
gender = mh_df['Gender'].value_counts().plot(kind='pie',autopct='%1.1f%%')

plt.legend()
plt.title('Percentage Distribution of Gender')
# Out:
# Text(0.5, 1.0, 'Percentage Distribution of Gender')

# %%
#mental health distribution by gender
mh_bygender = mh_df[['Gender','Mental_Health_History']]
mh_bygender
# Out:
#         Gender Mental_Health_History
# 0       Female                   Yes
# 1       Female                   Yes
# 2       Female                   Yes
# 3       Female                   Yes
# 4       Female                   Yes
# ...        ...                   ...
# 292359    Male                    No
# 292360    Male                    No
# 292361    Male                    No
# 292362    Male                    No
# 292363    Male                    No
#
# [290051 rows x 2 columns]

# %%
#mental health distribution by gender
mh_bygender = mh_df[['Gender','Mental_Health_History']].value_counts().sort_index(ascending=False)
mh_bygender
# Out:
# Gender  Mental_Health_History
# Male    Yes                      76250
#         No                       86010
#         Maybe                    75640
# Female  Yes                      15972
#         No                       17303
#         Maybe                    18876
# Name: count, dtype: int64

# %%
#mental health distribution by gender
import matplotlib.pyplot as plt 
import seaborn as sbn 

mh_bygender = mh_df[['Gender','Mental_Health_History']].value_counts().sort_index(ascending=False).plot(kind='bar',
                                                                                                        color=['r','g','y'])

for p in mh_bygender.patches:
    mh_bygender.annotate(str(p.get_height()),(p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 5), 
                textcoords='offset points')
    
plt.xticks(rotation=70)
plt.title('Mental Health Instance By Gender')
plt.ylabel('Frequency')
plt.xlabel('Gender & Mental Health History')
plt.ylim(0,90000)
# Out:
# (0.0, 90000.0)

# %%
#gender proportion of mental health respondents
mh_bygender_respdt = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_bygender_respdt.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_bygender_respdt[['Gender','Mental_Health_History']].groupby('Mental_Health_History').value_counts()
# Out:
# Mental_Health_History  Gender
# Yes                    Male      76250
#                        Female    15972
# Name: count, dtype: int64

# %%
#gender proportion of mental health respondents
import matplotlib.pyplot as plt 
import seaborn as sbn 

mh_bygender_respdt[['Gender','Mental_Health_History']].groupby('Mental_Health_History').value_counts().plot.pie(autopct='%1.1f%%')
plt.title('Gender Proportion of Mental Health Respondents')
plt.legend()

# %%
#respondents with mental health issues
mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
# Out:
#                  Timestamp  Gender        Country Occupation self_employed  \
# 0      2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1      2014-08-27 11:31:00  Female  United States  Corporate         Other
# 2      2014-08-27 11:32:00  Female  United States  Corporate         Other
# 3      2014-08-27 11:37:00  Female  United States  Corporate            No
# 4      2014-08-27 11:43:00  Female  United States  Corporate            No
# ...                    ...     ...            ...        ...           ...
# 291129 2015-07-27 23:25:00    Male  United States      Other           Yes
# 291130 2015-08-17 09:38:00    Male   South Africa      Other            No
# 291131 2015-08-25 19:59:00    Male  United States      Other            No
# 291132 2015-09-26 01:07:00    Male  United States      Other            No
# 291133 2016-02-01 23:04:00    Male  United States      Other            No
#
# ...

# %%
#top 20 countries with mental health Respondents
mh_by_country = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_country.head()
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
# 2 2014-08-27 11:32:00  Female  United States  Corporate         Other
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# ...

# %%
mh_by_country['Country'].value_counts(ascending=True).tail(20)
# Out:
# Country
# Singapore           250
# Russia              250
# Poland              257
# Belgium             257
# Israel              500
# Italy               500
# Switzerland         500
# South Africa        632
# New Zealand         632
# Brazil              750
# France              750
# India               882
# Sweden              889
# Germany            1500
# Ireland            1764
# Netherlands        1882
# Australia          1903
# Canada             5938
# United Kingdom    16362
# United States     53699
# Name: count, dtype: int64

# %%
#top 20 countries with mental health issues
import matplotlib.pyplot as plt
import seaborn as sbn

mh_by_country['Country'].value_counts(ascending=True).tail(20).plot(kind='barh',color='r')
plt.title('Top 20 Countries With Mental Health Respondents (2014-2016)')
plt.xlabel('Frequency')
plt.ylabel('Countries')
# Out:
# Text(0, 0.5, 'Countries')

# %%
#occupation distribution
mh_df.Occupation.value_counts().sort_values()
# Out:
# Occupation
# Business     49819
# Other        52375
# Corporate    60683
# Student      61268
# Housewife    65906
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_df.Occupation.value_counts().sort_values().plot(kind='pie',autopct='%1.1f%%')
plt.title('Occupations of Respondents')
plt.legend(loc='upper left')
#plt.xlim(0,70000)
#plt.xlabel('Frequency')

# %%
#mental health history by occupation
mh_df[['Occupation','Mental_Health_History']]
# Out:
#        Occupation Mental_Health_History
# 0       Corporate                   Yes
# 1       Corporate                   Yes
# 2       Corporate                   Yes
# 3       Corporate                   Yes
# 4       Corporate                   Yes
# ...           ...                   ...
# 292359   Business                    No
# 292360   Business                    No
# 292361   Business                    No
# 292362   Business                    No
# 292363   Business                    No
#
# [290051 rows x 2 columns]

# %%
#mh_df[['Occupation','Mental_Health_History']].value_counts().sort_index()
mh_df[['Occupation','Mental_Health_History']].groupby(by='Occupation').value_counts().sort_index()
# Out:
# Occupation  Mental_Health_History
# Business    Maybe                    13148
#             No                       20589
#             Yes                      16082
# Corporate   Maybe                    23029
#             No                       19132
#             Yes                      18522
# Housewife   Maybe                    23392
#             No                       22172
#             Yes                      20342
# Other       Maybe                    14489
#             No                       18517
#             Yes                      19369
# Student     Maybe                    20458
#             No                       22903
#             Yes                      17907
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

sbn.set_style('whitegrid')
mh_df[['Occupation','Mental_Health_History']].groupby(by='Occupation').value_counts().sort_index().plot(kind='barh',
                                                                                                        color=['y','g','r'])
plt.title('Mental Health History by Occupation')
plt.xlim(0,25000)
plt.xlabel('Frequency')
plt.ylabel('Occupation & Mental Health History')
# Out:
# Text(0, 0.5, 'Occupation & Mental Health History')

# %%
#self employed by gender
#mh_df[['Gender','self_employed']].groupby(by='Gender').value_counts()

# %%
#self employed proportion of respondents
mh_df.self_employed.value_counts().sort_values()
# Out:
# self_employed
# Other      5193
# Yes       29147
# No       255711
# Name: count, dtype: int64

# %%
#self employed proportion of respondents
import matplotlib.pyplot as plt
import seaborn as sbn 

sbn.set_style('whitegrid')
mh_df.self_employed.value_counts().sort_values().plot.pie(autopct='%1.1f%%')
#sbn.barplot(mh_df.self_employed.value_counts().sort_values())
#plt.legend()
plt.title('Self Employed Proportion of Respondents')
plt.legend()

# %%
#Self Employed with Mental Health History
mh_byself_employed = mh_df[mh_df['self_employed'].str.contains('Yes', case=False)]
mh_byself_employed.head()
# Out:
#              Timestamp  Gender         Country Occupation self_employed  \
# 17 2014-08-27 12:53:00  Female    South Africa  Corporate           Yes
# 43 2014-08-27 16:25:00  Female   United States  Corporate           Yes
# 49 2014-08-27 17:37:00  Female          Canada  Corporate           Yes
# 73 2014-08-28 11:50:00  Female   United States  Corporate           Yes
# 88 2014-08-29 05:57:00  Female  United Kingdom  Corporate           Yes
#
#    family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 17            Yes       Yes    1-14 days            Yes             No
# 43            Yes       Yes    1-14 days            Yes             No
# 49            Yes       Yes    1-14 days            Yes             No
# 73            Yes       Yes    1-14 days            Yes             No
# 88            Yes       Yes    1-14 days            Yes             No
#
#    Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# ...

# %%
mh_byself_employed['Mental_Health_History'].value_counts().sort_values()
# Out:
# Mental_Health_History
# Yes       9299
# Maybe     9400
# No       10448
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_byself_employed['Mental_Health_History'].value_counts().sort_values().plot.pie(autopct='%1.1f%%')
plt.title('Self Employed With Mental Health History')
plt.legend(loc='upper left')

# %%
mh_byself_employed[['self_employed','Mental_Health_History']].value_counts().sort_values().plot(kind='pie',autopct='%1.1f%%') 
plt.legend(loc='upper left')
plt.title('Proportions of Self Employed With Mental Health History (2014-2016)')
# Out:
# Text(0.5, 1.0, 'Proportions of Self Employed With Mental Health History (2014-2016)')

# %%
#family mental health history by respondents
mh_df.family_history.value_counts()
# Out:
# family_history
# No     175518
# Yes    114533
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sbn

mh_df.family_history.value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.legend()
plt.title('Family Mental Health History by Respondents')
# Out:
# Text(0.5, 1.0, 'Family Mental Health History by Respondents')

# %%
#mental health history by mental health respondents.
mh_by_familyhist = mh_df[mh_df['family_history'].str.contains('Yes', case=False)]
mh_by_familyhist.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
# 2 2014-08-27 11:32:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 1                   Yes      Medium               No            No
# 2                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 1             Yes                      No           No  2014      8   27
# 2             Yes                      No          Yes  2014      8   27

# %%
mh_by_familyhist['Mental_Health_History'].value_counts()
# Out:
# Mental_Health_History
# No       40472
# Maybe    37800
# Yes      36261
# Name: count, dtype: int64

# %%
#mental health history by mental health respondents.
import matplotlib.pyplot as plt
import seaborn as sbn

mh_by_familyhist['Mental_Health_History'].value_counts().plot.pie(autopct='%1.1f%%')

plt.legend(loc='upper left')
plt.title('Mental Health History by Mental Health Respondents')
# Out:
# Text(0.5, 1.0, 'Mental Health History by Mental Health Respondents')

# %%
#mental health treatment distribution
mh_df.treatment.value_counts()
# Out:
# treatment
# Yes    146184
# No     143867
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sbn

sbn.barplot(mh_df.treatment.value_counts())
plt.title('Mental Health Treatment Distribution')
plt.ylim(0,160000)
plt.xlabel('Treatment')
# Out:
# Text(0.5, 0, 'Treatment')

# %%
#treatment proportions of mental health respondents
mh_by_treatment = mh_df[mh_df['treatment'].str.contains('Yes', case=False)]
mh_by_treatment.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_treatment['Mental_Health_History'].value_counts()
# Out:
# Mental_Health_History
# No       51774
# Maybe    48072
# Yes      46338
# Name: count, dtype: int64

# %%
#treatment proportions of mental health respondents
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_by_treatment['Mental_Health_History'].value_counts().plot.pie(autopct='%1.1f%%')
plt.legend(loc='upper left')
plt.title('Treatment Proportions of Mental Health Respondents')
# Out:
# Text(0.5, 1.0, 'Treatment Proportions of Mental Health Respondents')

# %%
#indoor periods of mental health respondents
mh_days_indoors = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_days_indoors.head()
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
# 2 2014-08-27 11:32:00  Female  United States  Corporate         Other
# 3 2014-08-27 11:37:00  Female  United States  Corporate            No
# 4 2014-08-27 11:43:00  Female  United States  Corporate            No
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
# 2            Yes       Yes    1-14 days            Yes             No
# 3            Yes       Yes    1-14 days            Yes             No
# 4            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# ...

# %%
mh_days_indoors.Days_Indoors.value_counts().sort_values()
# Out:
# Days_Indoors
# More than 2 months    16329
# 31-60 days            16566
# 1-14 days             18391
# Go out Every day      19858
# 15-30 days            21078
# Name: count, dtype: int64

# %%
#days spent indoors by mental health respondents
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_days_indoors.Days_Indoors.value_counts().sort_values().plot.barh(color='orange')
plt.title('Indoor Periods of Mental Health Respondents')
plt.xlabel('Frequency')
# Out:
# Text(0.5, 0, 'Frequency')

# %%
#growing stress
mh_by_gs = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_gs.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
growing_stress = mh_by_gs['Growing_Stress'].value_counts().sort_index()
growing_stress
# Out:
# Growing_Stress
# Maybe    31186
# No       28141
# Yes      32895
# Name: count, dtype: int64

# %%
#Changes_Habits
mh_by_ch = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_ch.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
changes_habits = mh_by_ch['Changes_Habits'].value_counts().sort_index()
changes_habits
# Out:
# Changes_Habits
# Maybe    29608
# No       26800
# Yes      35814
# Name: count, dtype: int64

# %%
#Mood_Swings
mh_by_ms = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_ms.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_ms['Mood_Swings'].value_counts().sort_index()
# Out:
# Mood_Swings
# High      28504
# Low       27289
# Medium    36429
# Name: count, dtype: int64

# %%
#mood swings
import matplotlib.pyplot as plt 
import seaborn as sbn 

mh_by_ms['Mood_Swings'].value_counts().sort_index().plot(color='r',marker='*')
plt.title('Mood Swings Levels of Mental Health Respondents')
plt.ylabel('Frequency')
plt.xlabel('Mood Swings')
# Out:
# Text(0.5, 0, 'Mood Swings')

# %%
#coping struggles
mh_by_cs = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_cs.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_cs['Coping_Struggles'].value_counts().sort_values()
# Out:
# Coping_Struggles
# Yes    44092
# No     48130
# Name: count, dtype: int64

# %%
#coping struggles 
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_by_cs['Coping_Struggles'].value_counts().sort_values().plot.pie(autopct='%1.1f%%')
plt.title('Coping Struggles of Mental Health Respondents')
plt.legend(loc='upper left')
#plt.xticks(rotation=0)

# %%
#work interest
mh_by_wi = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_wi.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
work_interst = mh_by_wi['Work_Interest'].value_counts().sort_index()
work_interst
# Out:
# Work_Interest
# Maybe    29361
# No       32285
# Yes      30576
# Name: count, dtype: int64

# %%
#social weakness
mh_by_sw = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_sw.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
social_weakness = mh_by_sw['Social_Weakness'].value_counts().sort_index()
social_weakness
# Out:
# Social_Weakness
# Maybe    31186
# No       34241
# Yes      26795
# Name: count, dtype: int64

# %%
#mental health interview
mh_by_mhi = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_mhi.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mental_health_intv = mh_by_mhi['mental_health_interview'].value_counts().sort_index()
mental_health_intv
# Out:
# mental_health_interview
# Maybe    16452
# No       73013
# Yes       2757
# Name: count, dtype: int64

# %%
# Combine 5 mental health issues into a DataFrame
import matplotlib.pyplot as plt 
import seaborn as sbn

data = pd.DataFrame({
    'Growing Stress': growing_stress,
    'Changes in Habits': changes_habits,
    'Work Interest': work_interst,
    'Social Weakness': social_weakness,
    'Mental Health Interview': mental_health_intv
})

# Plot each series
for column in data.columns:
    sbn.lineplot(data=data[column], label=column, marker='o')

plt.title('Trends in Various Mental Health Issues')
plt.xlabel('Index')
plt.ylabel('Frequency')
plt.legend(title='Mental Health Issues')

# %%
#care options
mh_by_co = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_co.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_co['care_options'].value_counts().sort_index()
# Out:
# care_options
# No          37488
# Not sure    24648
# Yes         30086
# Name: count, dtype: int64

# %%
#how aware are respondents of their mental health
import matplotlib.pyplot as plt 
import seaborn as sbn

mh_by_co['care_options'].value_counts().sort_index().plot.bar(color=['g','y','r'])
plt.xticks(rotation=0)
plt.xlabel('Care Options')
plt.ylabel('Frequency')
plt.title('Awareness Level of Mental Health Respondents')
# Out:
# Text(0.5, 1.0, 'Awareness Level of Mental Health Respondents')

# %%
#Year distribution of respondents
mh_df['Year'].value_counts()
# Out:
# Year
# 2014    274985
# 2015     14676
# 2016       390
# Name: count, dtype: int64

# %%
#year distribution of mental health respondents
mh_by_yr = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_yr.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_yr['Year'].value_counts()
# Out:
# Year
# 2014    87430
# 2015     4667
# 2016      125
# Name: count, dtype: int64

# %%
#year distribution of mental health respondents
import matplotlib.pyplot as plt 
import seaborn as sbn

sbn.pointplot(mh_by_yr['Year'].value_counts(),color='r')
plt.title('Year Distribution of Mental Health Respondents')
# Out:
# Text(0.5, 1.0, 'Year Distribution of Mental Health Respondents')

# %%
#month distribution of respondents
mh_df['Month'].value_counts().sort_index()
# Out:
# Month
# 2      11125
# 4       1170
# 5        780
# 6        431
# 7        390
# 8     263039
# 9      11474
# 10       431
# 11       390
# 12       821
# Name: count, dtype: int64

# %%
#month distribution of mental health respondents
mh_by_mth = mh_df[mh_df['Mental_Health_History'].str.contains('Yes', case=False)]
mh_by_mth.head(2)
# Out:
#             Timestamp  Gender        Country Occupation self_employed  \
# 0 2014-08-27 11:29:00  Female  United States  Corporate         Other
# 1 2014-08-27 11:31:00  Female  United States  Corporate         Other
#
#   family_history treatment Days_Indoors Growing_Stress Changes_Habits  \
# 0             No       Yes    1-14 days            Yes             No
# 1            Yes       Yes    1-14 days            Yes             No
#
#   Mental_Health_History Mood_Swings Coping_Struggles Work_Interest  \
# 0                   Yes      Medium               No            No
# 1                   Yes      Medium               No            No
#
#   Social_Weakness mental_health_interview care_options  Year  Month  Day
# 0             Yes                      No     Not sure  2014      8   27
# 1             Yes                      No           No  2014      8   27

# %%
mh_by_mth['Month'].value_counts().sort_values()
# Out:
# Month
# 11      125
# 7       125
# 10      132
# 6       132
# 5       250
# 12      257
# 4       375
# 2      3535
# 9      3653
# 8     83638
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt 
import seaborn as sbn 

sbn.pointplot(mh_by_mth['Month'].value_counts().sort_values(),color='r',marker='.')
plt.title('Month Distributions of Mental Health Respondents')
plt.xlabel('Months')
# Out:
# Text(0.5, 0, 'Months')
